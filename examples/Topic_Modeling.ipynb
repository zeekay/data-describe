# %% [markdown]
# # Topic Modeling

# %%
import pandas as pd

# %%
from data_describe.text.topic_modeling import topic_model
# Out:
# UserWarning: The Dask Engine for Modin is experimental.

# %%
from sklearn.datasets import fetch_20newsgroups
categories = ['alt.atheism']
newsgroups_train = fetch_20newsgroups(subset='train', categories=categories)

# %%
df = pd.DataFrame({"text": newsgroups_train['data']})

# %%
df.head()
# Out:
#                                                 text
# 0  From: darice@yoyo.cc.monash.edu.au (Fred Rice)...
# 1  From: chrisb@tafe.sa.edu.au (Chris BELL)\nSubj...
# 2  Subject: Re: The Inimitable Rushdie\nFrom: kma...
# 3  From: timmbake@mcl.ucsb.edu (Bake Timmons)\nSu...
# 4  From: I3150101@dbstu1.rz.tu-bs.de (Benedikt Ro...

# %% [markdown]
# ## Explicitly providing number of topics

# %%
lda_model = topic_model(df.text, num_topics=2)
lda_model
# Out:
#         Topic 1 Topic 1 Coefficient Value    Topic 2 Topic 2 Coefficient Value
# Term 1       >>                     0.013         |>                     0.015
# Term 2       |>                     0.013          :                     0.015
# Term 3      God                     0.006        God                     0.006
# Term 4        -                     0.005         >>                     0.004
# Term 5      way                     0.004          A                     0.004
# Term 6      it.                     0.004          -                     0.004
# Term 7      had                     0.004   atheists                     0.004
# Term 8        :                     0.004   evidence                     0.004
# Term 9        |                     0.004      those                     0.004
# Term 10    good                     0.003  religious                     0.004

# %% [markdown]
# ## Guess optimal number of topics and show elbow plot

# %%
lda_model = topic_model(df.text, num_topics=None)
lda_model
# Out:
# Fitting topic model: 100%|██████████| 9/9 [00:17<00:00,  1.90s/it, topic_num=10]
#                    Topic 1 Topic 1 Coefficient Value   Topic 2  \
# Term 1                   +                     0.009        >>
# Term 2                  |>                     0.006     Jesus
# Term 3                 its                     0.005        |>
# Term 4                 way                     0.005     Islam
# Term 5                   A                     0.005      also
# Term 6                   :                     0.004       God
# Term 7                 For                     0.004      them
# Term 8   mangoe@cs.umd.edu                     0.004  evidence
# Term 9               peace                     0.004     moral
# Term 10                God                     0.004      time
#
#         Topic 2 Coefficient Value   Topic 3 Topic 3 Coefficient Value  \
# Term 1                      0.010        >>                     0.028
# Term 2                      0.006         :                     0.024
# Term 3                      0.006         -                     0.006
# Term 4                      0.005        |>                     0.004
# Term 5                      0.004     those                     0.004
# Term 6                      0.004         .                     0.004
# Term 7                      0.004       How                     0.004
# Term 8                      0.004      What                     0.004
# Term 9                      0.004  atheists                     0.004
# Term 10                     0.003   nothing                     0.004
#
#                              Topic 4 Topic 4 Coefficient Value   Topic 5  \
# Term 1                            |>                     0.056        >>
# Term 2                             :                     0.007  atheists
# Term 3   livesey@solntze.wpd.sgi.com                     0.006       God
# Term 4                        mathew                     0.005
# Term 5                      Livesey)                     0.005        am
# Term 6                             |                     0.005       may
# Term 7                          (Jon                     0.005       its
# Term 8                          What                     0.005         -
# Term 9                             -                     0.004   atheism
# Term 10                        Allan                     0.004       way
#
#         Topic 5 Coefficient Value   Topic 6 Topic 6 Coefficient Value  \
# Term 1                      0.008         :                     0.013
# Term 2                      0.007       God                     0.011
# Term 3                      0.006       our                     0.005
# Term 4                      0.006      also                     0.005
# Term 5                      0.005  atheists                     0.004
# Term 6                      0.004    cannot                     0.004
# Term 7                      0.004      most                     0.004
# Term 8                      0.004     Jesus                     0.004
# Term 9                      0.004     those                     0.004
# Term 10                     0.004       had                     0.004
#
#           Topic 7 Topic 7 Coefficient Value                      Topic 8  \
# Term 1        God                     0.009                           |>
# Term 2          -                     0.008                            :
# Term 3   evidence                     0.006                           >>
# Term 4          :                     0.005                        moral
# Term 5         >>                     0.005                       system
# Term 6        it.                     0.005                         (Jon
# Term 7   religion                     0.004                     Livesey)
# Term 8        had                     0.004                         They
# Term 9        For                     0.004                          had
# Term 10  atheists                     0.004  livesey@solntze.wpd.sgi.com
#
#         Topic 8 Coefficient Value Topic 9 Topic 9 Coefficient Value
# Term 1                      0.057      >>                     0.013
# Term 2                      0.024       |                     0.009
# Term 3                      0.007      |>                     0.007
# Term 4                      0.006       -                     0.006
# Term 5                      0.005     God                     0.006
# Term 6                      0.004   Islam                     0.006
# Term 7                      0.004    over                     0.005
# Term 8                      0.004    good                     0.005
# Term 9                      0.004    same                     0.004
# Term 10                     0.004   There                     0.004

# %%
lda_model.elbow_plot()
# Out:
# <AxesSubplot:title={'center':'Coherence Values Across Topic Numbers'}, xlabel='Number of Topics', ylabel='Coherence Values'>
